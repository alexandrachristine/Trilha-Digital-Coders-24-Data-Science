# %%
import pandas as pd

# %%
lista = [12, 23, 34, 45, 56, 67]

# %%
serie_pandas = pd.Series(lista)

# %%
print(serie_pandas[0])
# Out:
# 12

# %%
print(serie_pandas)
# Out:
# 0    12
# 1    23
# 2    34
# 3    45
# 4    56
# 5    67
# dtype: int64

# %%
notas = {'Tiago' : 8, 'Guilherme' : 9.5, 'Juca' : 6.2}

# %%
serie_notas = pd.Series(notas)

# %%
print (serie_notas)
# Out:
# Tiago        8.0
# Guilherme    9.5
# Juca         6.2
# dtype: float64

# %%
print (serie_notas['Tiago'])
# Out:
# 8.0

# %%
print (serie_notas.mean())
# Out:
# 7.8999999999999995

# %%
print (serie_notas.max())
# Out:
# 9.5

# %%
print (serie_notas.min())
# Out:
# 6.2

# %%
print (serie_notas.median())
print (serie_notas.describe())
# Out:
# 8.0
# count    3.000000
# mean     7.900000
# std      1.652271
# min      6.200000
# 25%      7.100000
# 50%      8.000000
# 75%      8.750000
# max      9.500000
# dtype: float64

# %%
print (ser
